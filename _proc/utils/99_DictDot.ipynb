# %% [raw]
# ---
# description: a utility class that converts json into an object that supports data
#   retrieval with dot notation
# output-file: dictdot.html
# title: DictDot
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(DictDot)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/utils/DictDot.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### DictDot
#
# >      DictDot (dictionary:dict, **kwargs)
#
# a utility class that converts json into an object that supports data retrieval with dot notation
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | dictionary | dict | dictionary to convert |
# | kwargs |  |  |

# %% [markdown]
# #### sample implementation of DictDot

# %%
foo = { "name": "my object", "description" : "please convert me", "type": "a good old fashioned dictionary"}

dd = DictDot(foo)

print(dd)

dd.type
# Out:
# DictDot(name='my object', description='please convert me', type='a good old fashioned dictionary')
# 'a good old fashioned dictionary'
