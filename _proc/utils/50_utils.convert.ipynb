# %% [raw]
# ---
# output-file: utils.convert.html
# title: Conversion utility functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(convert_epoch_millisecond_to_datetime)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/utils/convert.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_epoch_millisecond_to_datetime
#
# >      convert_epoch_millisecond_to_datetime (epoch:int)
#
# convert Epoch time with miliseconds to Date time

# %%
#| echo: false
#| output: asis
show_doc(convert_datetime_to_epoch_millisecond)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/utils/convert.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_datetime_to_epoch_millisecond
#
# >      convert_datetime_to_epoch_millisecond (datetime:datetime.datetime)
#
# convert DateTime to Epoch time with Miliseconds

# %%
import time
import datetime as dt 

cur_time = int(time.time()*1000)

cur_datetime =  convert_epoch_millisecond_to_datetime(cur_time)
print(cur_datetime)

test_time = convert_datetime_to_epoch_millisecond(cur_datetime)
print(test_time)

fctest.test_eq(test_time, cur_time)
# Out:
# 2023-01-07 00:51:35.572000
# 1673052695572

# %%
#| echo: false
#| output: asis
show_doc(convert_snake_to_pascal)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/utils/convert.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_snake_to_pascal
#
# >      convert_snake_to_pascal (str)
#
# converts 'snake_case_str' to 'snakeCaseStr'

# %%
convert_str = 'test_snake_case'

convert_snake_to_pascal(convert_str)
# Out:
# 'testSnakeCase'
