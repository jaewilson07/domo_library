# %% [raw]
# ---
# output-file: user.html
# title: SEARCH and GET Routes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [raw]
# # User Routes
# ---
# output-file: user_routes.html
# ---

# %% [markdown]
# ## Search Users

# %%
#| echo: false
#| output: asis
show_doc(get_all_users)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_all_users
#
# >      get_all_users (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                     debug_api:bool=False)

# %% [markdown]
# #### sample implementation of get_all_users

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo", domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)

res = await get_all_users(auth=token_auth)
pd.DataFrame(res.response[0:5])
# Out:
#            id  invitorUserId          displayName                         userName                     emailAddress  accepted      userType   timeZone  ...     created        role      roleId  rights  active  pending  systemUser  anonymous
# 0           0              2              monitor                          monitor                 monitor@domo.com     False  DOMO_SUPPORT  Etc/GMT+7  ...  1464820854  Privileged           1    31.0    True     True        True       True
# 1  1006847540     1893952720    Marc-Anton Clavel        marcanton.clavel@domo.com        marcanton.clavel@domo.com     False          USER        NaN  ...  1618579073  Privileged           2    31.0    True     True       False       True
# 2  1012895591     1893952720             JeMiller         JeMiller@marketaxess.com         JeMiller@marketaxess.com      True          USER        NaN  ...  1657049419         NaN  2097317660     NaN    True    False       False      False
# 3  1024352013     1893952720  Michael Shrifteylik  mshrifteylik@sportsresearch.com  mshrifteylik@sportsresearch.com      True          USER        NaN  ...  1667838056  Privileged           2    31.0    True    False       False      False
# 4  1026684838     1893952720     Ghofrane Yahmadi     ghofrane.yahmadi@audibene.de     ghofrane.yahmadi@audibene.de     False          USER        NaN  ...  1618579109  Privileged           2    31.0    True     True       False       True
#
# [5 rows x 17 columns]

# %%
#| echo: false
#| output: asis
show_doc(generate_search_users_body_by_id)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_search_users_body_by_id
#
# >      generate_search_users_body_by_id (user_ids:list[str])

# %%
#| echo: false
#| output: asis
show_doc(generate_search_users_body_by_email)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_search_users_body_by_email
#
# >      generate_search_users_body_by_email (user_email_ls:list[str])
#
# search does not appear to be case sensitive

# %%
user_email_ls = ['jae@onyxreporting.com',
                 'marcanton.clavel@domo.com']

generate_search_users_body_by_email(user_email_ls)
# Out:
# {'includeDeleted': False,
#  'includeSupport': False,
#  'limit': 200,
#  'offset': 0,
#  'sort': {'field': 'displayName', 'order': 'ASC'},
#  'filters': [{'filterType': 'text',
#    'field': 'emailAddress',
#    'text': 'jae@onyxreporting.com marcanton.clavel@domo.com'}]}

# %%
#| echo: false
#| output: asis
show_doc(process_v1_search_users)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L71){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_v1_search_users
#
# >      process_v1_search_users
# >                               (res_user_v1_search:domolibrary.client.ResponseG
# >                               etData.ResponseGetData)

# %%
#| echo: false
#| output: asis
show_doc(process_v1_search_users_user)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L59){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_v1_search_users_user
#
# >      process_v1_search_users_user (obj_user)

# %%
#| echo: false
#| output: asis
show_doc(search_users)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L77){target="_blank" style="float:right; font-size:smaller"}
#
# ### search_users
#
# >      search_users (auth:domolibrary.client.DomoAuth.DomoAuth, body:dict,
# >                    debug_api:bool=False, process_users:bool=True)

# %% [markdown]
# #### sample implementation of search_users

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo", domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)

search_email_body = generate_search_users_body_by_email(
    user_email_ls= ["jae@onyxreporting.com"]
)

res = await search_users(auth=token_auth, body=search_email_body, process_users=True, debug_api=False)

pd.DataFrame(res.response)
# Out:
#            id displayName  roleId               userName           emailAddress
# 0  1893952720  Jae Wilson       1  jae@onyxreporting.com  jae@onyxreporting.com

# %% [markdown]
# ## Search Publish

# %%
#| echo: false
#| output: asis
show_doc(search_virtual_user_by_subscriber_instance)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L100){target="_blank" style="float:right; font-size:smaller"}
#
# ### search_virtual_user_by_subscriber_instance
#
# >      search_virtual_user_by_subscriber_instance
# >                                                  (auth:domolibrary.client.Domo
# >                                                  Auth.DomoAuth,
# >                                                  subscriber_instance,
# >                                                  debug_api:bool=False)

# %% [markdown]
# # CRUD Routes and Attributes

# %%
#| echo: false
#| output: asis
show_doc(create_user)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L118){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_user
#
# >      create_user (auth:domolibrary.client.DomoAuth.DomoAuth, display_name:str,
# >                   email:str, role_id:int, debug_api:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(reset_password)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L137){target="_blank" style="float:right; font-size:smaller"}
#
# ### reset_password
#
# >      reset_password (auth:domolibrary.client.DomoAuth.DomoAuth, user_id:str,
# >                      new_password:str, debug_api:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(request_password_reset)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L158){target="_blank" style="float:right; font-size:smaller"}
#
# ### request_password_reset
#
# >      request_password_reset (domo_instance:str, email:str, locale='en-us',
# >                              debug_api:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(set_user_landing_page)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L171){target="_blank" style="float:right; font-size:smaller"}
#
# ### set_user_landing_page
#
# >      set_user_landing_page (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                             user_id:str, page_id:str, debug_api:bool=False)
