# %% [raw]
# ---
# description: a functional approach, routes only, to interacting with domo users.
# output-file: user.html
# title: User Routes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # GET Users

# %%
#| echo: false
#| output: asis
show_doc(get_all_users)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_all_users
#
# >      get_all_users (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                     debug_api:bool=False)
#
# retrieves all users from Domo

# %% [markdown]
# #### sample implementation of get_all_users

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo", 
    domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)

res = await get_all_users(auth=token_auth)
pd.DataFrame(res.response[0:5])
# Out:
#            id  invitorUserId          displayName                         userName                     emailAddress  accepted      userType  ...        role      roleId  rights active  pending  systemUser  anonymous
# 0           0              2              monitor                          monitor                 monitor@domo.com     False  DOMO_SUPPORT  ...  Privileged           1    31.0   True     True        True       True
# 1  1006847540     1893952720    Marc-Anton Clavel        marcanton.clavel@domo.com        marcanton.clavel@domo.com     False          USER  ...  Privileged           2    31.0   True     True       False       True
# 2  1012895591     1893952720             JeMiller         JeMiller@marketaxess.com         JeMiller@marketaxess.com      True          USER  ...         NaN  2097317660     NaN   True    False       False      False
# 3  1024352013     1893952720  Michael Shrifteylik  mshrifteylik@sportsresearch.com  mshrifteylik@sportsresearch.com      True          USER  ...  Privileged           2    31.0   True    False       False      False
# 4  1026684838     1893952720     Ghofrane Yahmadi     ghofrane.yahmadi@audibene.de     ghofrane.yahmadi@audibene.de     False          USER  ...  Privileged           2    31.0   True     True       False       True
#
# [5 rows x 17 columns]

# %% [markdown]
# # Search Users
# This series of functions searchse the v1_users_api.  The body of the search api can be retrieved by searching admin in the Domo User interface.

# %%
#| echo: false
#| output: asis
show_doc(generate_search_users_body_by_id)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_search_users_body_by_id
#
# >      generate_search_users_body_by_id (user_ids:list[str])
#
# search v1_users_search_api
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | user_ids | list | list of user ids to search |
# | **Returns** | **dict** | **dict to pass to search v1_users_search_api** |

# %%
#| echo: false
#| output: asis
show_doc(generate_search_users_body_by_email)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L42){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_search_users_body_by_email
#
# >      generate_search_users_body_by_email (user_email_ls:list[str])
#
# search v1_users_search_api
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | user_email_ls | list | list of user emails to search.  Note:  search does not appear to be case sensitive |
# | **Returns** | **dict** | **dict to pass to search v1_users_search_api** |

# %%
#| echo: false
#| output: asis
show_doc(process_v1_search_users)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_v1_search_users
#
# >      process_v1_search_users (v1_user_ls:list[dict])
#
# sanitizes the response from v1_users_search API and removes unecessary attributes
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | v1_user_ls | list | list of users from v1_users_search API |
# | **Returns** | **list** | **sanitized list of users.** |

# %%
#| echo: false
#| output: asis
show_doc(search_users)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L85){target="_blank" style="float:right; font-size:smaller"}
#
# ### search_users
#
# >      search_users (auth:domolibrary.client.DomoAuth.DomoAuth, body:dict,
# >                    debug_api:bool=False, process_users:bool=True)

# %% [markdown]
# #### sample implementation of search_users

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo", 
    domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)

search_email_body = generate_search_users_body_by_email(
    user_email_ls=["jae@onyxreporting.com"]
)

res = await search_users(
    auth=token_auth, 
    body=search_email_body, 
    process_users=True, 
    debug_api=False
)

pd.DataFrame(res.response)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Publish and Virtual Users
# > Virtual Users are necessary for assigning PDP policies when publish jobs are created.

# %%
#| echo: false
#| output: asis
show_doc(search_virtual_user_by_subscriber_instance)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L109){target="_blank" style="float:right; font-size:smaller"}
#
# ### search_virtual_user_by_subscriber_instance
#
# >      search_virtual_user_by_subscriber_instance
# >                                                  (auth:domolibrary.client.Domo
# >                                                  Auth.DomoAuth, subscriber_ins
# >                                                  tance_ls:list[str],
# >                                                  debug_api:bool=False)
#
# retrieve virtual users for subscriber instances tied to one publisher

# %% [markdown]
# #### sample of search virtual users by subscriber_instance

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo", 
    domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)

res = await search_virtual_user_by_subscriber_instance(
    auth = token_auth,
    subscriber_instance_ls = ['domo-dojo', 'test'],
    debug_api = False
    )


pd.DataFrame(res.response)
# Out:
#                                      id     publisherDomain      customerId    subscriberDomain                            virtualUserId        created  activeSubscriptions
# 0  2bcabab7-128e-4f47-8219-c8548588d7fc  domo-dojo.domo.com  mmmm-0012-0200  domo-dojo.domo.com  fc:ce69e5f0-ab88-46df-94ab-32b5f6dfd4e7  1674251102000                    0
# 1  57999e9b-e8a2-48ab-80c6-edf2627b71fc  domo-dojo.domo.com  mmmm-0012-0200       test.domo.com  fc:b3d7aaa1-9bc8-4481-9d34-c153a9b91b22  1674253476000                    0

# %% [markdown]
# # CRUD Routes and User Attributes

# %%
#| echo: false
#| output: asis
show_doc(create_user)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L130){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_user
#
# >      create_user (auth:domolibrary.client.DomoAuth.DomoAuth, display_name:str,
# >                   email:str, role_id:int, debug_api:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(set_user_landing_page)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L147){target="_blank" style="float:right; font-size:smaller"}
#
# ### set_user_landing_page
#
# >      set_user_landing_page (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                             user_id:str, page_id:str, debug_api:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(reset_password)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L162){target="_blank" style="float:right; font-size:smaller"}
#
# ### reset_password
#
# >      reset_password (auth:domolibrary.client.DomoAuth.DomoAuth, user_id:str,
# >                      new_password:str, debug_api:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(request_password_reset)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/domo_library/blob/main/domolibrary/routes/user.py#L182){target="_blank" style="float:right; font-size:smaller"}
#
# ### request_password_reset
#
# >      request_password_reset (domo_instance:str, email:str, locale='en-us',
# >                              debug_api:bool=False)
