# %% [raw]
# ---
# output-file: accounts.html
# title: Account Routes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_accounts)
# Out:
# ---
#
# ### get_accounts
#
# >      get_accounts (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                    debug_api:bool=False, session:Union[aiohttp.client.ClientSe
# >                    ssion,httpx.AsyncClient,NoneType]=None)
#
# retrieve a list of all the accounts the user has read access to.  Note users with "Manage all accounts" will retrieve all account objects

# %% [markdown]
# #### sample implementation of get_accounts

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo",
    domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)


res = await get_accounts(auth = token_auth)
pd.DataFrame(res.response)
# Out:
#    id      userId                                          name                    displayName  type  valid  ...     modifiedAt  modifiedBy  configurations  accountTemplateId  accountTemplateAuthorizationId  accountId
# 0   1  1893952720                          DataSet Copy Account           DataSet Copy Account  data   True  ...  1589100087000  1893952720              {}               None                            None          1
# 1   5  1893952720  Domo Governance Datasets Third Party Account  test_rename_using_classmethod  data   True  ...  1672872810000  1893952720              {}               None                            None          5
# 2  27  1893952720                          DataSet Copy Account           DataSet Copy Account  data   True  ...  1619083568000  1893952720              {}               None                            None         27
# 3  45  1893952720                       onyxReporting@gmail.com        onyxReporting@gmail.com  data   True  ...  1664924354000  1893952720              {}               None                            None         45
#
# [4 rows x 16 columns]

# %%
#| echo: false
#| output: asis
show_doc(get_account_from_id)
# Out:
# ---
#
# ### get_account_from_id
#
# >      get_account_from_id (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                           account_id:int, debug_api:bool=False,
# >                           session:aiohttp.client.ClientSession=None)
#
# retrieves metadata about an account

# %% [markdown]
# #### sample implementation of get_account_from_id

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo",
    domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)


res = await get_account_from_id(auth=token_auth, account_id = 1)
res.response
# Out:
# {'id': 1,
#  'userId': 1893952720,
#  'name': 'DataSet Copy Account',
#  'displayName': 'DataSet Copy Account',
#  'type': 'data',
#  'valid': True,
#  'dataProviderType': 'dataset-copy',
#  'credentialsType': 'fields',
#  'createdAt': 1589100087000,
#  'createdBy': 1893952720,
#  'modifiedAt': 1589100087000,
#  'modifiedBy': 1893952720,
#  'configurations': {},
#  'accountTemplateId': None,
#  'accountTemplateAuthorizationId': None,
#  'accountId': 1}

# %% [markdown]
# # Account Config

# %%
#| echo: false
#| output: asis
show_doc(get_account_config)
# Out:
# ---
#
# ### get_account_config
#
# >      get_account_config (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                          account_id:int, data_provider_type:str,
# >                          debug_api:bool=False, session:Union[aiohttp.client.Cl
# >                          ientSession,httpx.AsyncClient,NoneType]=None)

# %%
#| echo: false
#| output: asis
show_doc(AccountConfig_InvalidDataProvider)
# Out:
# ---
#
# ### AccountConfig_InvalidDataProvider
#
# >      AccountConfig_InvalidDataProvider (account_id:str,
# >                                         data_provider_type:str,
# >                                         domo_instance:str)
#
# Common base class for all non-exit exceptions.

# %% [markdown]
# #### sample implementation of get_account_config

# %%
import os
import pandas as pd

token_auth = dmda.DomoTokenAuth(
    domo_instance="domo-dojo",
    domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"]
)

res = await get_account_config(auth=token_auth, account_id=1, data_provider_type='dataset-copy')
res.response
# Out:
# {'instance': 'northshore-io-partner.domo.com', 'accessToken': '********'}

# %%
#| echo: false
#| output: asis
show_doc(update_account_config)
# Out:
# ---
#
# ### update_account_config
#
# >      update_account_config (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                             account_id:int, config_body:dict,
# >                             data_provider_type:str, debug_api:bool=False,
# >                             session:aiohttp.client.ClientSession=None)

# %%
#| echo: false
#| output: asis
show_doc(update_account_name)
# Out:
# ---
#
# ### update_account_name
#
# >      update_account_name (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                           account_id:int, account_name:str,
# >                           debug_api:bool=False,
# >                           session:aiohttp.client.ClientSession=None)

# %%
#| echo: false
#| output: asis
show_doc(create_account)
# Out:
# ---
#
# ### create_account
#
# >      create_account (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                      config_body:dict, debug_api:bool=False,
# >                      session:aiohttp.client.ClientSession=None)

# %%
#| echo: false
#| output: asis
show_doc(delete_account)
# Out:
# ---
#
# ### delete_account
#
# >      delete_account (auth:domolibrary.client.DomoAuth.DomoAuth,
# >                      account_id:str, debug_api:bool=False,
# >                      session:aiohttp.client.ClientSession=None)
