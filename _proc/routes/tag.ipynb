# %% [raw]
# ---
# description: routes for interacting with entity tags
# output-file: tag.html
# title: Tag Routes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
async def get_dataset_tags(auth: dmda.DomoFullAuth,
                            tag_ls: [str],
                            dataset_id: str,
                            debug_api: bool = False,
                            session: Optional[aiohttp.ClientSession] = None,
                            ):

    url = f"https://{auth.domo_instance}.domo.com/api/data/ui/v3/datasources/{dataset_id}/tags"

    return await gd.get_data(
        auth= auth,
        url=url,
        method='GET',
        debug_api=debug_api,
        body=tag_ls,
        session=session
    )

# %%
#| echo: false
#| output: asis
show_doc(set_dataset_tags)
# Out:
# ---
#
# ### set_dataset_tags
#
# >      set_dataset_tags (auth:domolibrary.DomoAuth.DomoFullAuth,
# >                        tag_ls:[<class'str'>], dataset_id:str,
# >                        debug_api:bool=False,
# >                        session:Optional[aiohttp.client.ClientSession]=None)

# %% [markdown]
# #### sample implementation of set_dataset_tags

# %%
import os 

token_auth = dmda.DomoTokenAuth(
    domo_access_token=os.environ["DOMO_DOJO_ACCESS_TOKEN"],
    domo_instance="domo-dojo",
)

# %%
#| echo: false
#| output: asis
show_doc(Dataset_Tags)
# Out:
# ---
#
# ### Dataset_Tags
#
# >      Dataset_Tags (dataset:<built-infunctionany>, tag_ls:[<class'str'>]=None)
